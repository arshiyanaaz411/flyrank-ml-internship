# %% [markdown]
# <a href="https://colab.research.google.com/github/arshiyanaaz411/flyrank-ml-internship/blob/main/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/arshiyanaaz411/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# My ML task type is Classification.
#
# I want to classify content items based on their expected performance level, such as high engagement or low engagement. Classification is suitable because the output belongs to different categories, and the model can learn patterns from historical data to make predictions.## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## The target I want to predict is the engagement level of a content item.
#
# The label can come from observed outcomes such as clicks, views, and user interactions. These signals can be combined to define whether a content item performs well or not.2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ##The success metric I would use is F1-score.
#
# F1-score is useful because it balances precision and recall. A higher F1-score means the model is making better predictions while reducing both false positives and false negatives. 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The unit of analysis is one content item.
#
# Each row in the dataframe represents one individual content item with its characteristics and engagement-related information. These features help understand patterns and predict future performance.## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

data = {
    "content_id": [1, 2, 3],
    "views": [1200, 500, 3000],
    "clicks": [150, 40, 450],
    "engagement_level": ["High", "Low", "High"]
}

df = pd.DataFrame(data)
df
# Out:
#    content_id  views  clicks engagement_level
# 0           1   1200     150             High
# 1           2    500      40              Low
# 2           3   3000     450             High

# %% [markdown]
# ##A fixed rule may not work well because content performance depends on multiple factors such as user behavior, content quality, timing, and engagement patterns.
#
# ML can identify complex patterns from historical data and make better predictions instead of relying on a single if-else rule. 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
